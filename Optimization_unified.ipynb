# %%
# %pip install pyscf openfermion openfermionpyscf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 MB 20.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 MB 13.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 63.8 MB/s eta 0:00:00
# ...

# %%
import os
os.chdir("/content/drive/MyDrive/Quasi_Symmetries")

from optimization_workflow import main

# Workflows: 'fixed_abc', 'shared_abc', 'local_abc'
main(workflow="fixed_abc", molecule="h4_linear")
# Out:
# === Individual operator + leakage analysis: h4_linear / fixed_abc_identity ===
#  i        <S_i>                  ||delta_i||           <delta_i|H|delta_i>       <H>_delta_i-E0         ||[H,S_i]psi||^2
#
# [h4_linear / fixed_abc_identity / S_0] leakage check
#   <psi|S|psi>                = +0.001239470200+0.000e+00j
#   ||delta||                  = 2.246052768409e-02
#   <delta|H|delta>            = +7.524104701468e-04+0.000e+00j
#   <H>_delta                  = +1.491471365215+0.000e+00j
#   <H>_delta - E0             = +3.451665010109e+00
#  0   +0.001239470200+0.00e+00j   +2.246052768409e-02   +7.524104701468e-04   +3.451665010109e+00   +6.143181940382e-03
#
# [h4_linear / fixed_abc_identity / S_1] leakage check
#   <psi|S|psi>                = +0.001222219792+0.000e+00j
#   ||delta||                  = 2.230415475742e-02
#   <delta|H|delta>            = +7.591276572815e-04-2.711e-20j
#   <H>_delta                  = +1.525960439870-5.449e-17j
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
main(workflow="fixed_abc", molecule="h4_rectangle")
# Out:
# === Individual operator + leakage analysis: h4_rectangle / fixed_abc_identity ===
#  i        <S_i>                  ||delta_i||           <delta_i|H|delta_i>       <H>_delta_i-E0         ||[H,S_i]psi||^2
#
# [h4_rectangle / fixed_abc_identity / S_0] leakage check
#   <psi|S|psi>                = +0.001580551723+0.000e+00j
#   ||delta||                  = 2.535269995484e-02
#   <delta|H|delta>            = +1.963777531565e-03+0.000e+00j
#   <H>_delta                  = +3.055229603551+0.000e+00j
#   <H>_delta - E0             = +3.803357061833e+00
#  0   +0.001580551723+0.00e+00j   +2.535269995484e-02   +1.963777531565e-03   +3.803357061833e+00   +9.403559058821e-03
#
# [h4_rectangle / fixed_abc_identity / S_1] leakage check
#   <psi|S|psi>                = +0.001580551723+0.000e+00j
#   ||delta||                  = 2.535269995484e-02
#   <delta|H|delta>            = +1.963777531565e-03+0.000e+00j
#   <H>_delta                  = +3.055229603551+0.000e+00j
# ...
